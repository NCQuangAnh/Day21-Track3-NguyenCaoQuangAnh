# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.06s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = "8"         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 6.47MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 46.4MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 95.3MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 128MB/s]
#
# tokenizer.json: downloading bytes:   0% 0.00/20.0M [00:00<?, ?B/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 9.41MB/s,  616kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 30.2MB/s, 1.98MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 5.17MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 4.88MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 32.5MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 19s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 143MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/9.32G [00:00<?, ?B/s]
# Downloading bytes:   2% 165M/9.32G [00:01<00:49, 186MB/s,  188MB/s  ]
# Downloading bytes:   2% 202M/9.32G [00:01<00:40, 226MB/s,  186MB/s  ]
# Downloading bytes:   3% 288M/9.32G [00:01<00:33, 270MB/s,  207MB/s  ]
# Downloading bytes:   6% 566M/9.32G [00:02<00:26, 336MB/s,  322MB/s  ]
# Downloading bytes:  17% 1.59G/9.32G [00:06<00:30, 256MB/s,  255MB/s  ]
# Downloading bytes:  32% 3.02G/9.32G [00:12<00:32, 193MB/s,  190MB/s  ]
# Downloading bytes:  35% 3.31G/9.32G [00:13<00:26, 223MB/s,  217MB/s  ]
# Downloading bytes:  37% 3.42G/9.32G [00:21<02:44, 35.9MB/s, 26.2MB/s  ]
# Downloading bytes:  38% 3.52G/9.32G [00:26<02:44, 35.3MB/s, 24.2MB/s  ]
# Downloading bytes:  38% 3.54G/9.32G [00:26<02:14, 43.1MB/s, 35.3MB/s  ]
# Downloading bytes:  44% 4.06G/9.32G [00:29<00:24, 213MB/s,  201MB/s  ]
# Downloading bytes:  45% 4.15G/9.32G [00:30<00:28, 183MB/s,  201MB/s  ]
# Downloading bytes:  46% 4.25G/9.32G [00:30<00:25, 201MB/s,  189MB/s  ]
# Downloading bytes:  50% 4.62G/9.32G [00:32<00:23, 203MB/s,  198MB/s  ]
# Downloading bytes:  60% 5.64G/9.32G [00:36<00:11, 327MB/s,  372MB/s  ]
# Downloading bytes:  62% 5.74G/9.32G [00:45<02:16, 26.3MB/s, 20.4MB/s  ]
# Downloading bytes:  66% 6.15G/9.32G [00:49<00:15, 208MB/s,  199MB/s  ]
# Downloading bytes:  69% 6.41G/9.32G [00:54<00:18, 156MB/s,  129MB/s  ]
# Downloading bytes:  74% 6.91G/9.32G [01:09<00:12, 192MB/s,  177MB/s  ]
# Downloading bytes:  75% 7.00G/9.32G [01:14<00:58, 39.9MB/s, 34.0MB/s  ]
# Downloading bytes:  77% 7.20G/9.32G [01:18<00:22, 92.9MB/s, 71.7MB/s  ]
# Downloading bytes:  78% 7.30G/9.32G [01:23<00:53, 38.0MB/s, 31.3MB/s  ]
# Downloading bytes:  81% 7.57G/9.32G [01:24<00:07, 238MB/s,  206MB/s  ]
# Downloading bytes:  84% 7.85G/9.32G [01:40<00:15, 93.2MB/s, 89.4MB/s  ]
# Downloading bytes:  85% 7.96G/9.32G [01:41<00:11, 116MB/s,  120MB/s  ]
# Downloading bytes:  86% 8.01G/9.32G [01:42<00:09, 143MB/s,  116MB/s  ]
# Downloading bytes:  86% 8.04G/9.32G [01:42<00:08, 150MB/s,  143MB/s  ]
# Reconstructing (incomplete total...):  78% 7.28G/9.32G [01:42<00:18, 108MB/s,  104MB/s  ]
#
# Fetching 2 files:  50% 1/2 [01:42<01:42, 102.61s/it]
# Reconstructing (incomplete total...):  81% 7.53G/9.32G [01:43<00:14, 123MB/s,  108MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [01:59<00:08, 150MB/s,  150MB/s  ]
# Reconstructing (incomplete total...):  89% 8.34G/9.32G [02:03<00:18, 53.9MB/s, 83.9MB/s  ]
# Reconstructing (incomplete total...):  91% 8.50G/9.32G [02:03<00:12, 63.3MB/s, 53.9MB/s  ]
# Reconstructing (incomplete total...):  94% 8.77G/9.32G [02:13<00:11, 46.4MB/s, 63.3MB/s  ]
# Reconstructing (incomplete total...):  97% 9.05G/9.32G [02:17<00:05, 50.0MB/s, 46.4MB/s  ]
# Reconstructing (incomplete total...):  99% 9.22G/9.32G [02:18<00:01, 60.1MB/s, 50.0MB/s  ]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [02:18<00:00, 67.7MB/s, 60.1MB/s  ]
#
# Fetching 2 files: 100% 2/2 [02:18<00:00, 69.37s/it]
# Download complete: 100% 8.05G/8.05G [02:18<00:00, 150MB/s,  150MB/s  ]
# Download complete: 100% 8.05G/8.05G [02:18<00:00, 58.0MB/s,  150MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [02:18<00:00, 67.1MB/s, 67.7MB/s  ]
# Loading weights: 100% 426/426 [00:30<00:00, 13.82it/s]
#   [(a) base + naive prompt/target] batch 1/2     14s elapsed  ~   14s left
#   [(a) base + naive prompt/target] batch 2/2     26s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 26s
#   [(a) base + naive prompt/regression] batch 1/2      6s elapsed  ~    6s left
#   [(a) base + naive prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 12s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  3272ms
#   [(b) base + optimized prompt/target] batch 1/2      4s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 2/2      8s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 8s
#   [(b) base + optimized prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(b) base + optimized prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 12s
# (b) base + optimized prompt  target=0.688  regression=0.750  format=1.000  998ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 3272.3298756249974,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.6875,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 998.3507132499909,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 244s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 959.03it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.63it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 6887.85 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 46319.74 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.384', 'grad_norm': '2.581', 'learning_rate': '8.83e-05', 'entropy': '1.03', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7694', 'epoch': '0.7111'}
# {'loss': '0.1391', 'grad_norm': '0.615', 'learning_rate': '6.434e-05', 'entropy': '0.2644', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9594', 'epoch': '1'}
# {'loss': '0.02874', 'grad_norm': '1.121', 'learning_rate': '3.566e-05', 'entropy': '0.03963', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9876', 'epoch': '1.356'}
# {'loss': '0.0166', 'grad_norm': '0.2803', 'learning_rate': '1.17e-05', 'entropy': '0.02218', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.994', 'epoch': '1.711'}
# {'loss': '0.02654', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01592', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9965', 'epoch': '2'}
# {'train_runtime': '924.6', 'train_samples_per_second': '0.487', 'train_steps_per_second': '0.032', 'train_loss': '0.6263', 'epoch': '2'}
# 100% 30/30 [15:24<00:00, 30.82s/it]
# train 925s  final loss 0.6263
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 925.0,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6263,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 992s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1054.64it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.55it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1060.37it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.68it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 7014.09 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 46107.02 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.823', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8271', 'grad_norm': '1.985', 'learning_rate': '8.83e-05', 'entropy': '0.9442', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8422', 'epoch': '0.7111'}
# {'loss': '0.1493', 'grad_norm': '1.31', 'learning_rate': '6.434e-05', 'entropy': '0.2907', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9587', 'epoch': '1'}
# {'loss': '0.03868', 'grad_norm': '0.8433', 'learning_rate': '3.566e-05', 'entropy': '0.06586', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9879', 'epoch': '1.356'}
# {'loss': '0.02091', 'grad_norm': '0.2037', 'learning_rate': '1.17e-05', 'entropy': '0.0313', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9909', 'epoch': '1.711'}
# {'loss': '0.02696', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02232', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.995', 'epoch': '2'}
# {'train_runtime': '816.5', 'train_samples_per_second': '0.588', 'train_steps_per_second': '0.037', 'train_loss': '0.5377', 'epoch': '2'}
# 100% 30/30 [13:36<00:00, 27.22s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1090.70it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.65it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10006.56 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45940.92 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
# {'loss': '1.606', 'grad_norm': 'nan', 'learning_rate': '6.434e-06', 'entropy': '1.178', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7176', 'epoch': '1'}
# {'loss': '1.326', 'grad_norm': '4.63', 'learning_rate': '3.566e-06', 'entropy': '1.103', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.7564', 'epoch': '1.356'}
# {'loss': '1.141', 'grad_norm': '4.213', 'learning_rate': '1.17e-06', 'entropy': '1.077', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.7979', 'epoch': '1.711'}
# {'loss': '1.119', 'grad_norm': 'nan', 'learning_rate': '3.381e-08', 'entropy': '1.069', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.7905', 'epoch': '2'}
# {'train_runtime': '949.1', 'train_samples_per_second': '0.506', 'train_steps_per_second': '0.032', 'train_loss': '1.57', 'epoch': '2'}
# 100% 30/30 [15:49<00:00, 31.64s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 909.24it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.45it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10337.25 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45197.24 examples/s]
#   precision fix: recast 496/496 trainable tensors bf16 -> fp32 for the fp16 GradScaler
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.155', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.34', 'num_tokens': '7479', 'mean_token_accuracy': '0.656', 'epoch': '0.3556'}
# {'loss': '1.731', 'grad_norm': '3.368', 'learning_rate': '8.83e-05', 'entropy': '1.287', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7214', 'epoch': '0.7111'}
# {'loss': '0.2408', 'grad_norm': '1.019', 'learning_rate': '6.434e-05', 'entropy': '0.3825', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9382', 'epoch': '1'}
# {'loss': '0.0513', 'grad_norm': '1.023', 'learning_rate': '3.566e-05', 'entropy': '0.07534', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9829', 'epoch': '1.356'}
# {'loss': '0.03019', 'grad_norm': '0.3238', 'learning_rate': '1.17e-05', 'entropy': '0.0355', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9884', 'epoch': '1.711'}
# {'loss': '0.02674', 'grad_norm': '3.368', 'learning_rate': '3.381e-07', 'entropy': '0.03056', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.992', 'epoch': '2'}
# {'train_runtime': '1016', 'train_samples_per_second': '0.472', 'train_steps_per_second': '0.03', 'train_loss': '0.7058', 'epoch': '2'}
# 100% 30/30 [16:56<00:00, 33.88s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 32464896 | 0.0001 | 0.6263 | 925.0 | 12.01 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 283 | 32456704 | 0.0001 | 0.5377 | 816.8 | 12.02 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 32464896 | 1e-05 | 1.5704 | 949.6 | 12.01 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 32464896 | 0.0001 | 0.7058 | 1016.8 | 7.09 |
#
# -- NB4 ok in 2954s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.688 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 638.06it/s]
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Download complete: :           |  0.00B
# Loading weights: 100% 426/426 [00:33<00:00, 12.64it/s]
#   [ft/target] batch 1/2      7s elapsed  ~    7s left
#   [ft/target] batch 2/2     12s elapsed  ~    0s left
#   [ft/target] done: 8 prompts in 12s
#   [ft/regression] batch 1/2      9s elapsed  ~    9s left
#   [ft/regression] batch 2/2     20s elapsed  ~    0s left
#   [ft/regression] done: 8 prompts in 20s
# fine-tune: {'target': 0.9375, 'regression': 0.875, 'format': 1.0, 'latency_ms': 1505.5442812499678, 'n': 8, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.75 | 0.0 | 3272.3 | 8 |
# | (b) base + optimized prompt | 0.6875 | 0.75 | 1.0 | 998.4 | 8 |
# | (c) LoRA fine-tune | 0.9375 | 0.875 | 1.0 | 1505.5 | 8 |
# PASSED
#  - beat the optimized-prompt baseline by +0.250 with +0.125 general-capability change.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1053.32it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.40it/s]
#   [attn_only/target] batch 1/2      4s elapsed  ~    4s left
#   [attn_only/target] batch 2/2      7s elapsed  ~    0s left
#   [attn_only/target] done: 8 prompts in 7s
# attn_only: target=0.938  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 972.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.46it/s]
#   [wrong_lr/target] batch 1/2     20s elapsed  ~   20s left
#   [wrong_lr/target] batch 2/2     40s elapsed  ~    0s left
#   [wrong_lr/target] done: 8 prompts in 40s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1132.98it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:36<00:00, 11.75it/s]
#   [qlora/target] batch 1/2      7s elapsed  ~    7s left
#   [qlora/target] batch 2/2     15s elapsed  ~    0s left
#   [qlora/target] done: 8 prompts in 15s
# qlora: target=0.844  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 0.9375 | 1.0 | 1505.5 | 8 |
# | attn_only | 0.9375 | 1.0 | 917.3 | 8 |
# | wrong_lr | 0.0 | 0.0 | 4976.9 | 8 |
# | qlora | 0.8438 | 1.0 | 1850.4 | 8 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 3 | Cho mình hỏi, mình đặt bình giữ nhiệt mã đơn VN804124. Chưa thấy tiền. | 0.75 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "bình giữ nhiệt", "sentiment": |
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 0.75 | {"intent": "san_pham_loi", "urgency": "trung_binh", "product": "nồi chiên không dầu", "sen |
# | 0 | Cho mình hỏi, mình đặt chuột không dây mã đơn VN232232. Cho tôi trả lạ | 1.0 | {"intent": "doi_tra", "urgency": "cao", "product": "chuột không dây", "sentiment": "tich_c |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 4 | Cho mình hỏi, mình đặt đèn bàn LED mã đơn VN339109. Vỡ khi nhận. Gấp.  | 1.0 | {"intent": "san_pham_loi", "urgency": "cao", "product": "đèn bàn LED", "sentiment": "trung |
# | 6 | Xin chào, mình đặt balo laptop mã đơn DH863123. Đổi size. Hỏi cho biết | 1.0 | {"intent": "doi_tra", "urgency": "thap", "product": "balo laptop", "sentiment": "tieu_cuc" |
# | 7 | Alo shop, mình đặt máy xay sinh tố mã đơn OD126693. Muốn đổi. Đã 3 ngà | 1.0 | {"intent": "doi_tra", "urgency": "trung_binh", "product": "máy xay sinh tố", "sentiment":  |
#
# -- NB5 ok in 267s
#
# ----------------------------------------
# stage timings
#   nb1        19s  (0.3 min)
#   nb2       244s  (4.1 min)
#   nb3       992s  (16.5 min)
#   nb4      2954s  (49.2 min)
#   nb5       267s  (4.4 min)
#   total    4475s (74.6 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.70s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [ FAIL ] full eval set used                               EVAL_LIMIT=8 — this run scored 8 target items, not the full set. Smoke mode is for iterating; unset EVAL_LIMIT and re-run NB2+NB5 to submit.
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.688
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     32,456,704 vs 32,464,896 trainable params
# [  ok  ] verdict recorded                                 PASSED (target Δ +0.250, regression Δ +0.125)
#
# 23 passed · 0 warnings · 3 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 40
# drwxr-xr-x  2 root root 4096 Aug 21 14:10 .
# drwxr-xr-x 15 root root 4096 Aug 21 12:55 ..
# -rw-r--r--  1 root root  435 Aug 21 14:10 autopsy.json
# -rw-r--r--  1 root root  480 Aug 21 13:00 baselines_frozen.json
# -rw-r--r--  1 root root    0 Aug 21 12:53 .gitkeep
# -rw-r--r--  1 root root  592 Aug 21 12:56 mask_proof.json
# -rw-r--r--  1 root root 2206 Aug 21 14:10 qualitative.json
# -rw-r--r--  1 root root 1100 Aug 21 14:06 runs.csv
# -rw-r--r--  1 root root  277 Aug 21 12:56 template_check.json
# -rw-r--r--  1 root root  115 Aug 21 12:56 token_stats.json
# -rw-r--r--  1 root root  754 Aug 21 14:07 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,False,32464896,925.0,12.01,0.6263,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",T4,unsloth/Qwen3.5-4B,fp16,attn-only,2,283,566,0.0001,False,32456704,816.8,12.02,0.5377,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,1e-05,False,32464896,949.6,12.01,1.5704,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,T4,unsloth/Qwen3.5-4B,fp16,text-linear,12,16,32,0.0001,True,32464896,1016.8,7.09,0.7058,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.75,
#       "format": 0.0,
#       "latency_ms": 3272.3,
#       "n": 8
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.6875,
#       "regression": 0.75,
#       "format": 1.0,
#       "latency_ms": 998.4,
#       "n": 8
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 0.9375,
#       "regression": 0.875,
#       "format": 1.0,
#       "latency_ms": 1505.5,
#       "n": 8
#     }
#   ],
#   "verdict": {
#     "passed": true,
#     "reasons": [
#       "beat the optimized-prompt baseline by +0.250 with +0.125 general-capability change."
#     ],
#     "target_delta": 0.25,
#     "regression_delta": 0.125
#   },
#   "valid_trace_rate": 0.0
# }
